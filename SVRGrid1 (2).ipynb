# %%
#importing the libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
dependent=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['linear'],
              'C':[10,100],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(),param_grid,refit = True, verbose = 3,n_jobs=-1)
regressor=grid.fit(independent,dependent)
Y_pred=regressor.predict(independent)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
from sklearn.metrics import r2_score
r_score=r2_score(dependent,Y_pred)
r_score
# Out:
# 0.5483146013160243

# %%
re=grid.cv_results_
print("The R_score value for best parameter ():".format(grid.best_params_))
# Out:
# The R_score value for best parameter ():

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.206244      0.013223         0.030185        0.001397       10
# 1       0.208455      0.016227         0.029787        0.003151       10
# 2       0.429519      0.020452         0.027813        0.004461      100
# 3       0.349952      0.056895         0.015658        0.002218      100
#
#   param_gamma param_kernel                                            params  \
# 0        auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 1       scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 2        auto       linear   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 3       scale       linear  {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0          -0.018943           0.029886           0.022167           0.003112
# 1          -0.018943           0.029886           0.022167           0.003112
# 2           0.559313           0.521798           0.547691           0.538805
# 3           0.559313           0.521798           0.547691           0.538805
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0          -0.066653        -0.006086        0.034672                3
# 1          -0.066653        -0.006086        0.034672                3
# 2           0.508518         0.535225        0.018122                1
# 3           0.508518         0.535225        0.018122                1

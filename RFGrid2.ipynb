# %%
#importing the libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
dependent=dataset['charges']

# %%
#from sklearn.tree import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid= {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'max_features':[None,'sqrt','log2'],'n_estimators':[50,100]}

grid = GridSearchCV(RandomForestRegressor(),param_grid, refit = True, verbose = 3,n_jobs=-1)
#fitting the model for grid search
regressor=grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 50}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.281235      0.008077         0.014404        0.002159
# 1        0.565014      0.007928         0.019287        0.003979
# 2        0.210956      0.007425         0.013178        0.002230
# 3        0.442452      0.015930         0.019352        0.001722
# 4        0.230131      0.012085         0.011868        0.002734
# 5        0.461542      0.015507         0.022999        0.003498
# 6        0.298975      0.015732         0.010738        0.002265
# 7        0.598930      0.022539         0.018238        0.002984
# 8        0.233222      0.014218         0.010372        0.001615
# 9        0.490381      0.027272         0.019543        0.002552
# 10       0.273461      0.018464         0.011202        0.002853
# 11       0.495656      0.023397         0.016917        0.004941
# 12       1.290237      0.024215         0.012000        0.003310
# 13       2.702033      0.111350         0.017616        0.003003
# 14       0.781825      0.034611         0.007841        0.002431
# 15       1.661986      0.115061         0.019569        0.004464
# 16       0.857427      0.049996         0.011938        0.001860
# 17       1.598057      0.116479         0.019479        0.001470
# 18       0.491702      0.040812         0.010267        0.003406
# 19       0.932058      0.038766         0.018384        0.003620
# 20       0.365548      0.004338         0.010871        0.001906
# 21       0.744646      0.021625         0.019349        0.002827
# 22       0.376843      0.017096         0.010952        0.003007
# 23       0.608499      0.030426         0.011218        0.002233
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  50
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  50
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6     friedman_mse               None                  50
# 7     friedman_mse               None                 100
# 8     friedman_mse               sqrt                  50
# 9     friedman_mse               sqrt                 100
# 10    friedman_mse               log2                  50
# 11    friedman_mse               log2                 100
# 12  absolute_error               None                  50
# 13  absolute_error               None                 100
# 14  absolute_error               sqrt                  50
# 15  absolute_error               sqrt                 100
# 16  absolute_error               log2                  50
# 17  absolute_error               log2                 100
# 18         poisson               None                  50
# 19         poisson               None                 100
# 20         poisson               sqrt                  50
# 21         poisson               sqrt                 100
# 22         poisson               log2                  50
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.846545
# 1   {'criterion': 'squared_error', 'max_features':...           0.846158
# 2   {'criterion': 'squared_error', 'max_features':...           0.860597
# 3   {'criterion': 'squared_error', 'max_features':...           0.856300
# 4   {'criterion': 'squared_error', 'max_features':...           0.861093
# 5   {'criterion': 'squared_error', 'max_features':...           0.858738
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.844156
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.848105
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.862274
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.860116
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.858318
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.855179
# 12  {'criterion': 'absolute_error', 'max_features'...           0.835523
# 13  {'criterion': 'absolute_error', 'max_features'...           0.838594
# 14  {'criterion': 'absolute_error', 'max_features'...           0.854675
# 15  {'criterion': 'absolute_error', 'max_features'...           0.860675
# 16  {'criterion': 'absolute_error', 'max_features'...           0.859489
# 17  {'criterion': 'absolute_error', 'max_features'...           0.855891
# 18  {'criterion': 'poisson', 'max_features': None,...           0.849133
# 19  {'criterion': 'poisson', 'max_features': None,...           0.847874
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860558
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856058
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.859409
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.855960
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.769120           0.854702           0.814321
# 1            0.774858           0.852905           0.817178
# 2            0.773763           0.858805           0.828592
# 3            0.781065           0.862647           0.829911
# 4            0.773835           0.862563           0.825760
# 5            0.780381           0.863990           0.825813
# 6            0.773955           0.851750           0.810565
# 7            0.773103           0.854621           0.824592
# 8            0.780856           0.861922           0.829950
# 9            0.783436           0.862538           0.827162
# 10           0.775739           0.856941           0.823517
# 11           0.780605           0.859028           0.829522
# 12           0.766329           0.849828           0.824666
# 13           0.768992           0.845671           0.827484
# 14           0.777353           0.849190           0.826306
# 15           0.782797           0.857902           0.826361
# 16           0.780250           0.849827           0.829508
# 17           0.780034           0.862992           0.829739
# 18           0.766703           0.853649           0.819521
# 19           0.771519           0.854492           0.824833
# 20           0.779636           0.858419           0.823491
# 21           0.777384           0.864837           0.826016
# 22           0.776611           0.863016           0.822896
# 23           0.781119           0.864274           0.829765
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.844978         0.825933        0.031552               19
# 1            0.836249         0.825470        0.028026               21
# 2            0.837724         0.831896        0.031535               12
# 3            0.839640         0.833913        0.028874                7
# 4            0.832027         0.831056        0.032243               14
# 5            0.840895         0.833963        0.030003                6
# 6            0.832995         0.822684        0.028048               23
# 7            0.837312         0.827547        0.029065               18
# 8            0.839120         0.834824        0.029808                1
# 9            0.837461         0.834142        0.028677                4
# 10           0.835129         0.829929        0.030134               15
# 11           0.841795         0.833226        0.028298               10
# 12           0.831716         0.821612        0.028835               24
# 13           0.835850         0.823318        0.027780               22
# 14           0.839165         0.829338        0.027728               16
# 15           0.843055         0.834158        0.028442                3
# 16           0.848190         0.833453        0.028317                8
# 17           0.843757         0.834483        0.029476                2
# 18           0.840588         0.825919        0.031845               20
# 19           0.839968         0.827737        0.029799               17
# 20           0.842999         0.833021        0.029812               11
# 21           0.842079         0.833275        0.030884                9
# 22           0.837429         0.831872        0.031284               13
# 23           0.839043         0.834032        0.029115                5
